# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
#tf.enable_eager_execution()

import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
from tensorflow.keras import layers
from tensorflow import keras
from pathlib import Path
home = str(Path.home())

tf.keras.backend.clear_session()  # For easy reset of notebook state.
print(cv2.__version__)
print(tf.__version__)
#assert tf.executing_eagerly() == True

class_names = ["cloudy", "sunny"]
IMG_HEIGHT = 64
IMG_WIDTH = 64
IMG_CHN = 3
RGB_MEAN = [0.485, 0.456, 0.406]
RGB_STD = [0.229, 0.224, 0.225]

def generate_generator(generator, path, batch_size = 16, img_height = IMG_HEIGHT, img_width = IMG_WIDTH):

        gen = generator.flow_from_directory(path,
                                            classes = class_names,
                                            target_size = (img_height,img_width),
                                            batch_size = batch_size,
                                            shuffle=True, 
                                            seed=7)
        while True:
            X,y = gen.next()    
            yield X, y #Yield both images and their mutual label
                
class Dataloader:
    def __init__(self, data_path,  batch_size = 16):
        
       	train_imgen = keras.preprocessing.image.ImageDataGenerator(rotation_range = 10,\
										width_shift_range = 0.35, height_shift_range = 0.35,\
										horizontal_flip = True, rescale = 1/255.0)

        test_imgen = keras.preprocessing.image.ImageDataGenerator(rescale = 1/255.0)

        self.train_generator = generate_generator(train_imgen,
                                               path = str(data_path) + "train/",
                                               batch_size=batch_size)       

        self.val_generator = generate_generator(test_imgen,
                                              path = str(data_path)+ "val/",
                                              batch_size=batch_size)              

        
    def load_image(self, val = False):
        if val:
            return next(self.val_generator)
        else:
            return next(self.train_generator)
    
    def load_dl(self):
        return [self.train_generator, self.val_generator]
# Out:
# 4.2.0
# 1.14.0

# %%
data_path = "/home/charles/dataset/bi_weather_dataset/"
dl = Dataloader(data_path)
train_generator, val_generator = dl.load_dl()

# %%
def WeatherSceneClassifier(): 
    
    
    input_img = layers.Input(shape = (64,64,3), dtype = 'float32', name = "input_img" )
    x = layers.Conv2D(16, 3, strides=(2, 2), name = "conv1",\
                                padding='valid', activation="relu", kernel_initializer='glorot_uniform')(input_img)
    x = layers.Conv2D(32, 3, strides=(2, 2), name = "conv2",\
                                padding='valid', activation="relu", kernel_initializer='glorot_uniform')(x)
    x = layers.MaxPool2D()(x)
    x = layers.Conv2D(64, 3, strides=(2, 2), name = "conv3",\
                                padding='valid', activation="relu", kernel_initializer='glorot_uniform')(x)
    x = layers.Conv2D(128, 3, strides=(1, 1), name = "conv4",\
                                padding='valid', activation="relu", kernel_initializer='glorot_uniform')(x)
    x = layers.Flatten()(x)
    x = layers.Dense(32, activation= 'relu', name = "fc1", kernel_initializer = 'glorot_uniform')(x)
    output = layers.Dense(2, activation= 'softmax', name = "output", kernel_initializer = 'glorot_uniform')(x)
    

    model = keras.Model(inputs=[input_img], outputs=output)
    model.compile(optimizer = keras.optimizers.Adam(learning_rate=lr),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.CategoricalAccuracy()])
    
    return model

#create DNN model

lr = 5e-4
batch_size = 16
trainset_size = 9000
valset_size = 800
epochs = 200
checkpoint_path = "./weights_01/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)


model = WeatherSceneClassifier()
#model.load_weights("./training_simple_finetuned_83/cp.ckpt")
keras.utils.plot_model(model, 'weather_classification.png')



model.fit_generator(train_generator,
                                steps_per_epoch=trainset_size/batch_size,
                                epochs = epochs,
                                validation_data = val_generator,
                                validation_steps = valset_size/batch_size,
                                use_multiprocessing = True,
                                shuffle=True,
                                verbose = 3,
                                callbacks=[cp_callback])
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-5311f7fd1a51> in <module>
#      52                                 shuffle=True,
#      53                                 verbose = 3,
# ---> 54                                 callbacks=[cp_callback])
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     218     step = 0
#     219     while step < target_steps:
# --> 220       batch_data = _get_next_batch(generator, mode)
#     221       if batch_data is None:
#     222         if is_dataset:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in _get_next_batch(generator, mode)
#     360   """Retrieves the next batch of input data."""
#     361   try:
# --> 362     generator_output = next(generator)
#     363   except (StopIteration, errors.OutOfRangeError):
#     364     return None
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/utils/data_utils.py in get(self)
#     892     try:
#     893       while self.is_running():
# --> 894         inputs = self.queue.get(block=True).get()
#     895         self.queue.task_done()
#     896         if inputs is not None:
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
 class Dataloader:
    def __init__(self, data_path,  batch_size = 16):
        
        test_imgen = keras.preprocessing.image.ImageDataGenerator(rescale = 1/255.0)
        self.test_generator = generate_generator(test_imgen,
                                              path = str(data_path)+ "test/",
                                              batch_size=batch_size)            
    def load_dl(self):
        return self.test_generator
    
batch_size = 16
checkpoint_path = "/checkpoints/" + "weights_hyb02/cp.ckpt"
testset_size = 188
epochs = 500
dl = Dataloader("./mixed_vehicle_dataset/")
test_generator = dl.load_dl()
#checkpoint_path = "training_simple_new_new/cp.ckpt"
#checkpoint_dir = os.path.dirname(checkpoint_path)
#cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                 save_weights_only=True,
#                                                 verbose=1)


model = CarColorClassificationNet()
model.load_weights(checkpoint_path)
#model = tf.keras.experimental.load_from_saved_model("./models/")
#model.compile(optimizer = keras.optimizers.Adam(learning_rate=lr),
#              loss=tf.keras.losses.CategoricalCrossentropy(),
#              metrics=[tf.keras.metrics.CategoricalAccuracy()])

loss, acc = model.evaluate_generator(test_generator,steps = testset_size/batch_size,use_multiprocessing = True)
print("Restored model, loss: {}, accuracy: {:5.2f}%".format(loss, acc*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-22eb1b0f967e> in <module>
#      22
#      23
# ---> 24 model = CarColorClassificationNet()
#      25 model.load_weights(checkpoint_path)
#      26 #model = tf.keras.experimental.load_from_saved_model("./models/")
#
# NameError: name 'CarColorClassificationNet' is not defined

# %%
def freeze_session(session, keep_var_names=None, output_names=None, clear_devices=True):
    """
    Freezes the state of a session into a pruned computation graph.

    Creates a new computation graph where variable nodes are replaced by
    constants taking their current value in the session. The new graph will be
    pruned so subgraphs that are not necessary to compute the requested
    outputs are removed.
    @param session The TensorFlow session to be frozen.
    @param keep_var_names A list of variable names that should not be frozen,
                          or None to freeze all the variables in the graph.
    @param output_names Names of the relevant graph outputs.
    @param clear_devices Remove the device directives from the graph for better portability.
    @return The frozen graph definition.
    """
    graph = session.graph
    with graph.as_default():
        freeze_var_names = list(set(v.op.name for v in tf.global_variables()).difference(keep_var_names or []))
        output_names = output_names or []
        output_names += [v.op.name for v in tf.global_variables()]
        input_graph_def = graph.as_graph_def()
        if clear_devices:
            for node in input_graph_def.node:
                node.device = ""
        frozen_graph = tf.graph_util.convert_variables_to_constants(
            session, input_graph_def, output_names, freeze_var_names)
        return frozen_graph

# %%
from keras import backend as K

# Create, compile and train model...

frozen_graph = freeze_session(K.get_session(),
                              output_names=[out.op.name for out in model.outputs])
# Out:
# WARNING:tensorflow:From <ipython-input-6-0d92ab84a915>:26: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/charles/.local/lib/python3.6/site-packages/tensorflow/python/framework/graph_util_impl.py:270: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 55 variables.
# INFO:tensorflow:Converted 55 variables to const ops.
# Using TensorFlow backend.

# %%
print([out.op.name for out in model.outputs])
print([out.op.name for out in model.inputs])
# Out:
# ['output_2/Softmax']
# ['input_img_2', 'input_hist_2']

# %%
tf.train.write_graph(frozen_graph, "./", "hyb01.pb", as_text=False)
[n.name for n in tf.get_default_graph().as_graph_def().node]

print("model output to pb successful.")
# Out:
# ['keras_learning_phase/input',
#  'keras_learning_phase',
#  'input_img',
#  'conv1/kernel/Initializer/random_uniform/shape',
#  'conv1/kernel/Initializer/random_uniform/min',
#  'conv1/kernel/Initializer/random_uniform/max',
#  'conv1/kernel/Initializer/random_uniform/RandomUniform',
#  'conv1/kernel/Initializer/random_uniform/sub',
#  'conv1/kernel/Initializer/random_uniform/mul',
#  'conv1/kernel/Initializer/random_uniform',
#  'conv1/kernel',
#  'conv1/kernel/IsInitialized/VarIsInitializedOp',
#  'conv1/kernel/Assign',
#  'conv1/kernel/Read/ReadVariableOp',
#  'conv1/bias/Initializer/zeros',
#  'conv1/bias',
#  'conv1/bias/IsInitialized/VarIsInitializedOp',
#  'conv1/bias/Assign',
#  'conv1/bias/Read/ReadVariableOp',
#  'conv1/dilation_rate',
#  'conv1/Conv2D/ReadVariableOp',
#  'conv1/Conv2D',
#  'conv1/BiasAdd/ReadVariableOp',
#  'conv1/BiasAdd',
#  'conv1/Relu',
#  'max_pooling2d/MaxPool',
#  'conv2/kernel/Initializer/random_uniform/shape',
#  'conv2/kernel/Initializer/random_uniform/min',
#  'conv2/kernel/Initializer/random_uniform/max',
#  'conv2/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2/kernel/Initializer/random_uniform/sub',
#  'conv2/kernel/Initializer/random_uniform/mul',
#  'conv2/kernel/Initializer/random_uniform',
#  'conv2/kernel',
#  'conv2/kernel/IsInitialized/VarIsInitializedOp',
#  'conv2/kernel/Assign',
#  'conv2/kernel/Read/ReadVariableOp',
#  'conv2/bias/Initializer/zeros',
#  'conv2/bias',
#  'conv2/bias/IsInitialized/VarIsInitializedOp',
#  'conv2/bias/Assign',
#  'conv2/bias/Read/ReadVariableOp',
#  'conv2/dilation_rate',
#  'conv2/Conv2D/ReadVariableOp',
#  'conv2/Conv2D',
#  'conv2/BiasAdd/ReadVariableOp',
#  'conv2/BiasAdd',
#  'conv2/Relu',
#  'max_pooling2d_1/MaxPool',
#  'conv3/kernel/Initializer/random_uniform/shape',
#  'conv3/kernel/Initializer/random_uniform/min',
#  'conv3/kernel/Initializer/random_uniform/max',
#  'conv3/kernel/Initializer/random_uniform/RandomUniform',
#  'conv3/kernel/Initializer/random_uniform/sub',
#  'conv3/kernel/Initializer/random_uniform/mul',
#  'conv3/kernel/Initializer/random_uniform',
#  'conv3/kernel',
#  'conv3/kernel/IsInitialized/VarIsInitializedOp',
#  'conv3/kernel/Assign',
#  'conv3/kernel/Read/ReadVariableOp',
#  'conv3/bias/Initializer/zeros',
#  'conv3/bias',
#  'conv3/bias/IsInitialized/VarIsInitializedOp',
#  'conv3/bias/Assign',
#  'conv3/bias/Read/ReadVariableOp',
#  'conv3/dilation_rate',
#  'conv3/Conv2D/ReadVariableOp',
#  'conv3/Conv2D',
#  'conv3/BiasAdd/ReadVariableOp',
#  'conv3/BiasAdd',
#  'conv3/Relu',
#  'max_pooling2d_2/MaxPool',
#  'flatten/Shape',
#  'flatten/strided_slice/stack',
#  'flatten/strided_slice/stack_1',
#  'flatten/strided_slice/stack_2',
#  'flatten/strided_slice',
#  'flatten/Reshape/shape/1',
#  'flatten/Reshape/shape',
#  'flatten/Reshape',
#  'input_hist',
#  'concatenate/concat/axis',
#  'concatenate/concat',
#  'fc1/kernel/Initializer/random_uniform/shape',
#  'fc1/kernel/Initializer/random_uniform/min',
#  'fc1/kernel/Initializer/random_uniform/max',
#  'fc1/kernel/Initializer/random_uniform/RandomUniform',
#  'fc1/kernel/Initializer/random_uniform/sub',
#  'fc1/kernel/Initializer/random_uniform/mul',
#  'fc1/kernel/Initializer/random_uniform',
#  'fc1/kernel',
#  'fc1/kernel/IsInitialized/VarIsInitializedOp',
#  'fc1/kernel/Assign',
#  'fc1/kernel/Read/ReadVariableOp',
#  'fc1/bias/Initializer/zeros',
#  'fc1/bias',
#  'fc1/bias/IsInitialized/VarIsInitializedOp',
#  'fc1/bias/Assign',
#  'fc1/bias/Read/ReadVariableOp',
#  'fc1/MatMul/ReadVariableOp',
#  'fc1/MatMul',
#  'fc1/BiasAdd/ReadVariableOp',
#  'fc1/BiasAdd',
#  'fc1/Relu',
#  'output/kernel/Initializer/random_uniform/shape',
#  'output/kernel/Initializer/random_uniform/min',
#  'output/kernel/Initializer/random_uniform/max',
#  'output/kernel/Initializer/random_uniform/RandomUniform',
#  'output/kernel/Initializer/random_uniform/sub',
#  'output/kernel/Initializer/random_uniform/mul',
#  'output/kernel/Initializer/random_uniform',
#  'output/kernel',
#  'output/kernel/IsInitialized/VarIsInitializedOp',
#  'output/kernel/Assign',
#  'output/kernel/Read/ReadVariableOp',
#  'output/bias/Initializer/zeros',
#  'output/bias',
#  'output/bias/IsInitialized/VarIsInitializedOp',
#  'output/bias/Assign',
#  'output/bias/Read/ReadVariableOp',
#  'output/MatMul/ReadVariableOp',
#  'output/MatMul',
#  'output/BiasAdd/ReadVariableOp',
#  'output/BiasAdd',
#  'output/Softmax',
#  'total/Initializer/zeros',
#  'total',
#  'total/IsInitialized/VarIsInitializedOp',
#  'total/Assign',
#  'total/Read/ReadVariableOp',
#  'count/Initializer/zeros',
#  'count',
#  'count/IsInitialized/VarIsInitializedOp',
#  'count/Assign',
#  'count/Read/ReadVariableOp',
#  'output_target',
#  'metrics/categorical_accuracy/ArgMax/dimension',
#  'metrics/categorical_accuracy/ArgMax',
#  'metrics/categorical_accuracy/ArgMax_1/dimension',
#  'metrics/categorical_accuracy/ArgMax_1',
#  'metrics/categorical_accuracy/Equal',
#  'metrics/categorical_accuracy/Cast',
#  'metrics/categorical_accuracy/Const',
#  'metrics/categorical_accuracy/Sum',
#  'metrics/categorical_accuracy/AssignAddVariableOp',
#  'metrics/categorical_accuracy/ReadVariableOp',
#  'metrics/categorical_accuracy/Size',
#  'metrics/categorical_accuracy/Cast_1',
#  'metrics/categorical_accuracy/AssignAddVariableOp_1',
#  'metrics/categorical_accuracy/ReadVariableOp_1',
#  'metrics/categorical_accuracy/div_no_nan/ReadVariableOp',
#  'metrics/categorical_accuracy/div_no_nan/ReadVariableOp_1',
#  'metrics/categorical_accuracy/div_no_nan',
#  'metrics/categorical_accuracy/Identity',
#  'loss/output_loss/Const',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Rank',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Shape',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Rank_1',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Shape_1',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Sub/y',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Sub',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Slice/begin',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Slice/size',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Slice',
#  'loss/output_loss/softmax_cross_entropy_with_logits/concat/values_0',
#  'loss/output_loss/softmax_cross_entropy_with_logits/concat/axis',
#  'loss/output_loss/softmax_cross_entropy_with_logits/concat',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Reshape',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Rank_2',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Shape_2',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Sub_1/y',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Sub_1',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Slice_1/begin',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Slice_1/size',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Slice_1',
#  'loss/output_loss/softmax_cross_entropy_with_logits/concat_1/values_0',
#  'loss/output_loss/softmax_cross_entropy_with_logits/concat_1/axis',
#  'loss/output_loss/softmax_cross_entropy_with_logits/concat_1',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Reshape_1',
#  'loss/output_loss/softmax_cross_entropy_with_logits',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Sub_2/y',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Sub_2',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Slice_2/begin',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Slice_2/size',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Slice_2',
#  'loss/output_loss/softmax_cross_entropy_with_logits/Reshape_2',
#  'loss/output_loss/weighted_loss/Const',
#  'loss/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/weights/shape',
#  'loss/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/weights/rank',
#  'loss/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/values/shape',
#  'loss/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/values/rank',
#  'loss/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/static_scalar_check_success',
#  'loss/output_loss/weighted_loss/broadcast_weights/ones_like/Shape',
#  'loss/output_loss/weighted_loss/broadcast_weights/ones_like/Const',
#  'loss/output_loss/weighted_loss/broadcast_weights/ones_like',
#  'loss/output_loss/weighted_loss/broadcast_weights',
#  'loss/output_loss/weighted_loss/Mul',
#  'loss/output_loss/Const_1',
#  'loss/output_loss/Sum',
#  'loss/output_loss/num_elements',
#  'loss/output_loss/num_elements/Cast',
#  'loss/output_loss/Const_2',
#  'loss/output_loss/Sum_1',
#  'loss/output_loss/value',
#  'loss/mul/x',
#  'loss/mul',
#  'Placeholder',
#  'AssignVariableOp',
#  'ReadVariableOp',
#  'Placeholder_1',
#  'AssignVariableOp_1',
#  'ReadVariableOp_1',
#  'VarIsInitializedOp',
#  'VarIsInitializedOp_1',
#  'VarIsInitializedOp_2',
#  'VarIsInitializedOp_3',
#  'VarIsInitializedOp_4',
#  'VarIsInitializedOp_5',
#  'VarIsInitializedOp_6',
#  'VarIsInitializedOp_7',
#  'VarIsInitializedOp_8',
#  'VarIsInitializedOp_9',
#  'VarIsInitializedOp_10',
#  'VarIsInitializedOp_11',
#  'init',
#  'Adam/gradients/Shape',
#  'Adam/gradients/grad_ys_0',
#  'Adam/gradients/Fill',
#  'Adam/gradients/loss/mul_grad/Mul',
#  'Adam/gradients/loss/mul_grad/Mul_1',
#  'Adam/gradients/loss/output_loss/value_grad/Shape',
#  'Adam/gradients/loss/output_loss/value_grad/Shape_1',
#  'Adam/gradients/loss/output_loss/value_grad/BroadcastGradientArgs',
#  'Adam/gradients/loss/output_loss/value_grad/div_no_nan',
#  'Adam/gradients/loss/output_loss/value_grad/Sum',
#  'Adam/gradients/loss/output_loss/value_grad/Reshape',
#  'Adam/gradients/loss/output_loss/value_grad/Neg',
#  'Adam/gradients/loss/output_loss/value_grad/div_no_nan_1',
#  'Adam/gradients/loss/output_loss/value_grad/div_no_nan_2',
#  'Adam/gradients/loss/output_loss/value_grad/mul',
#  'Adam/gradients/loss/output_loss/value_grad/Sum_1',
#  'Adam/gradients/loss/output_loss/value_grad/Reshape_1',
#  'Adam/gradients/loss/output_loss/Sum_1_grad/Reshape/shape',
#  'Adam/gradients/loss/output_loss/Sum_1_grad/Reshape',
#  'Adam/gradients/loss/output_loss/Sum_1_grad/Const',
#  'Adam/gradients/loss/output_loss/Sum_1_grad/Tile',
#  'Adam/gradients/loss/output_loss/Sum_grad/Reshape/shape',
#  'Adam/gradients/loss/output_loss/Sum_grad/Reshape',
#  'Adam/gradients/loss/output_loss/Sum_grad/Shape',
#  'Adam/gradients/loss/output_loss/Sum_grad/Tile',
#  'Adam/gradients/loss/output_loss/weighted_loss/Mul_grad/Shape',
#  'Adam/gradients/loss/output_loss/weighted_loss/Mul_grad/Shape_1',
#  'Adam/gradients/loss/output_loss/weighted_loss/Mul_grad/BroadcastGradientArgs',
#  'Adam/gradients/loss/output_loss/weighted_loss/Mul_grad/Mul',
#  'Adam/gradients/loss/output_loss/weighted_loss/Mul_grad/Sum',
#  'Adam/gradients/loss/output_loss/weighted_loss/Mul_grad/Reshape',
#  'Adam/gradients/loss/output_loss/weighted_loss/Mul_grad/Mul_1',
#  'Adam/gradients/loss/output_loss/weighted_loss/Mul_grad/Sum_1',
#  'Adam/gradients/loss/output_loss/weighted_loss/Mul_grad/Reshape_1',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits/Reshape_2_grad/Shape',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits/Reshape_2_grad/Reshape',
#  'Adam/gradients/zeros_like',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits_grad/ExpandDims/dim',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits_grad/ExpandDims',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits_grad/mul',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits_grad/LogSoftmax',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits_grad/Neg',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits_grad/ExpandDims_1/dim',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits_grad/ExpandDims_1',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits_grad/mul_1',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits/Reshape_grad/Shape',
#  'Adam/gradients/loss/output_loss/softmax_cross_entropy_with_logits/Reshape_grad/Reshape',
#  'Adam/gradients/output/BiasAdd_grad/BiasAddGrad',
#  'Adam/gradients/output/MatMul_grad/MatMul',
#  'Adam/gradients/output/MatMul_grad/MatMul_1',
#  'Adam/gradients/fc1/Relu_grad/ReluGrad',
#  'Adam/gradients/fc1/BiasAdd_grad/BiasAddGrad',
#  'Adam/gradients/fc1/MatMul_grad/MatMul',
#  'Adam/gradients/fc1/MatMul_grad/MatMul_1',
#  'Adam/gradients/concatenate/concat_grad/Rank',
#  'Adam/gradients/concatenate/concat_grad/mod',
#  'Adam/gradients/concatenate/concat_grad/Shape',
#  'Adam/gradients/concatenate/concat_grad/ShapeN',
#  'Adam/gradients/concatenate/concat_grad/ConcatOffset',
#  'Adam/gradients/concatenate/concat_grad/Slice',
#  'Adam/gradients/concatenate/concat_grad/Slice_1',
#  'Adam/gradients/flatten/Reshape_grad/Shape',
#  'Adam/gradients/flatten/Reshape_grad/Reshape',
#  'Adam/gradients/max_pooling2d_2/MaxPool_grad/MaxPoolGrad',
#  'Adam/gradients/conv3/Relu_grad/ReluGrad',
#  'Adam/gradients/conv3/BiasAdd_grad/BiasAddGrad',
#  'Adam/gradients/conv3/Conv2D_grad/ShapeN',
#  'Adam/gradients/conv3/Conv2D_grad/Conv2DBackpropInput',
#  'Adam/gradients/conv3/Conv2D_grad/Conv2DBackpropFilter',
#  'Adam/gradients/max_pooling2d_1/MaxPool_grad/MaxPoolGrad',
#  'Adam/gradients/conv2/Relu_grad/ReluGrad',
#  'Adam/gradients/conv2/BiasAdd_grad/BiasAddGrad',
#  'Adam/gradients/conv2/Conv2D_grad/ShapeN',
#  'Adam/gradients/conv2/Conv2D_grad/Conv2DBackpropInput',
#  'Adam/gradients/conv2/Conv2D_grad/Conv2DBackpropFilter',
#  'Adam/gradients/max_pooling2d/MaxPool_grad/MaxPoolGrad',
#  'Adam/gradients/conv1/Relu_grad/ReluGrad',
#  'Adam/gradients/conv1/BiasAdd_grad/BiasAddGrad',
#  'Adam/gradients/conv1/Conv2D_grad/ShapeN',
#  'Adam/gradients/conv1/Conv2D_grad/Conv2DBackpropInput',
#  'Adam/gradients/conv1/Conv2D_grad/Conv2DBackpropFilter',
#  'Adam/iter/Initializer/zeros',
#  'Adam/iter',
#  'Adam/iter/IsInitialized/VarIsInitializedOp',
#  'Adam/iter/Assign',
#  'Adam/iter/Read/ReadVariableOp',
#  'Adam/beta_1/Initializer/initial_value',
#  'Adam/beta_1',
#  'Adam/beta_1/IsInitialized/VarIsInitializedOp',
#  'Adam/beta_1/Assign',
#  'Adam/beta_1/Read/ReadVariableOp',
#  'Adam/beta_2/Initializer/initial_value',
#  'Adam/beta_2',
#  'Adam/beta_2/IsInitialized/VarIsInitializedOp',
#  'Adam/beta_2/Assign',
#  'Adam/beta_2/Read/ReadVariableOp',
#  'Adam/decay/Initializer/initial_value',
#  'Adam/decay',
#  'Adam/decay/IsInitialized/VarIsInitializedOp',
#  'Adam/decay/Assign',
#  'Adam/decay/Read/ReadVariableOp',
#  'Adam/learning_rate/Initializer/initial_value',
#  'Adam/learning_rate',
#  'Adam/learning_rate/IsInitialized/VarIsInitializedOp',
#  'Adam/learning_rate/Assign',
#  'Adam/learning_rate/Read/ReadVariableOp',
#  'Adam/conv1/kernel/m/Initializer/zeros',
#  'Adam/conv1/kernel/m',
#  'Adam/conv1/kernel/m/IsInitialized/VarIsInitializedOp',
#  'Adam/conv1/kernel/m/Assign',
#  'Adam/conv1/kernel/m/Read/ReadVariableOp',
#  'Adam/conv1/bias/m/Initializer/zeros',
#  'Adam/conv1/bias/m',
#  'Adam/conv1/bias/m/IsInitialized/VarIsInitializedOp',
#  'Adam/conv1/bias/m/Assign',
#  'Adam/conv1/bias/m/Read/ReadVariableOp',
#  'Adam/conv2/kernel/m/Initializer/zeros/shape_as_tensor',
#  'Adam/conv2/kernel/m/Initializer/zeros/Const',
#  'Adam/conv2/kernel/m/Initializer/zeros',
#  'Adam/conv2/kernel/m',
#  'Adam/conv2/kernel/m/IsInitialized/VarIsInitializedOp',
#  'Adam/conv2/kernel/m/Assign',
#  'Adam/conv2/kernel/m/Read/ReadVariableOp',
#  'Adam/conv2/bias/m/Initializer/zeros',
#  'Adam/conv2/bias/m',
#  'Adam/conv2/bias/m/IsInitialized/VarIsInitializedOp',
#  'Adam/conv2/bias/m/Assign',
#  'Adam/conv2/bias/m/Read/ReadVariableOp',
#  'Adam/conv3/kernel/m/Initializer/zeros/shape_as_tensor',
#  'Adam/conv3/kernel/m/Initializer/zeros/Const',
#  'Adam/conv3/kernel/m/Initializer/zeros',
#  'Adam/conv3/kernel/m',
#  'Adam/conv3/kernel/m/IsInitialized/VarIsInitializedOp',
#  'Adam/conv3/kernel/m/Assign',
#  'Adam/conv3/kernel/m/Read/ReadVariableOp',
#  'Adam/conv3/bias/m/Initializer/zeros',
#  'Adam/conv3/bias/m',
#  'Adam/conv3/bias/m/IsInitialized/VarIsInitializedOp',
#  'Adam/conv3/bias/m/Assign',
#  'Adam/conv3/bias/m/Read/ReadVariableOp',
#  'Adam/fc1/kernel/m/Initializer/zeros/shape_as_tensor',
#  'Adam/fc1/kernel/m/Initializer/zeros/Const',
#  'Adam/fc1/kernel/m/Initializer/zeros',
#  'Adam/fc1/kernel/m',
#  'Adam/fc1/kernel/m/IsInitialized/VarIsInitializedOp',
#  'Adam/fc1/kernel/m/Assign',
#  'Adam/fc1/kernel/m/Read/ReadVariableOp',
#  'Adam/fc1/bias/m/Initializer/zeros',
#  'Adam/fc1/bias/m',
#  'Adam/fc1/bias/m/IsInitialized/VarIsInitializedOp',
#  'Adam/fc1/bias/m/Assign',
#  'Adam/fc1/bias/m/Read/ReadVariableOp',
#  'Adam/output/kernel/m/Initializer/zeros',
#  'Adam/output/kernel/m',
#  'Adam/output/kernel/m/IsInitialized/VarIsInitializedOp',
#  'Adam/output/kernel/m/Assign',
#  'Adam/output/kernel/m/Read/ReadVariableOp',
#  'Adam/output/bias/m/Initializer/zeros',
#  'Adam/output/bias/m',
#  'Adam/output/bias/m/IsInitialized/VarIsInitializedOp',
#  'Adam/output/bias/m/Assign',
#  'Adam/output/bias/m/Read/ReadVariableOp',
#  'Adam/conv1/kernel/v/Initializer/zeros',
#  'Adam/conv1/kernel/v',
#  'Adam/conv1/kernel/v/IsInitialized/VarIsInitializedOp',
#  'Adam/conv1/kernel/v/Assign',
#  'Adam/conv1/kernel/v/Read/ReadVariableOp',
#  'Adam/conv1/bias/v/Initializer/zeros',
#  'Adam/conv1/bias/v',
#  'Adam/conv1/bias/v/IsInitialized/VarIsInitializedOp',
#  'Adam/conv1/bias/v/Assign',
#  'Adam/conv1/bias/v/Read/ReadVariableOp',
#  'Adam/conv2/kernel/v/Initializer/zeros/shape_as_tensor',
#  'Adam/conv2/kernel/v/Initializer/zeros/Const',
#  'Adam/conv2/kernel/v/Initializer/zeros',
#  'Adam/conv2/kernel/v',
#  'Adam/conv2/kernel/v/IsInitialized/VarIsInitializedOp',
#  'Adam/conv2/kernel/v/Assign',
#  'Adam/conv2/kernel/v/Read/ReadVariableOp',
#  'Adam/conv2/bias/v/Initializer/zeros',
#  'Adam/conv2/bias/v',
#  'Adam/conv2/bias/v/IsInitialized/VarIsInitializedOp',
#  'Adam/conv2/bias/v/Assign',
#  'Adam/conv2/bias/v/Read/ReadVariableOp',
#  'Adam/conv3/kernel/v/Initializer/zeros/shape_as_tensor',
#  'Adam/conv3/kernel/v/Initializer/zeros/Const',
#  'Adam/conv3/kernel/v/Initializer/zeros',
#  'Adam/conv3/kernel/v',
#  'Adam/conv3/kernel/v/IsInitialized/VarIsInitializedOp',
#  'Adam/conv3/kernel/v/Assign',
#  'Adam/conv3/kernel/v/Read/ReadVariableOp',
#  'Adam/conv3/bias/v/Initializer/zeros',
#  'Adam/conv3/bias/v',
#  'Adam/conv3/bias/v/IsInitialized/VarIsInitializedOp',
#  'Adam/conv3/bias/v/Assign',
#  'Adam/conv3/bias/v/Read/ReadVariableOp',
#  'Adam/fc1/kernel/v/Initializer/zeros/shape_as_tensor',
#  'Adam/fc1/kernel/v/Initializer/zeros/Const',
#  'Adam/fc1/kernel/v/Initializer/zeros',
#  'Adam/fc1/kernel/v',
#  'Adam/fc1/kernel/v/IsInitialized/VarIsInitializedOp',
#  'Adam/fc1/kernel/v/Assign',
#  'Adam/fc1/kernel/v/Read/ReadVariableOp',
#  'Adam/fc1/bias/v/Initializer/zeros',
#  'Adam/fc1/bias/v',
#  'Adam/fc1/bias/v/IsInitialized/VarIsInitializedOp',
#  'Adam/fc1/bias/v/Assign',
#  'Adam/fc1/bias/v/Read/ReadVariableOp',
#  'Adam/output/kernel/v/Initializer/zeros',
#  'Adam/output/kernel/v',
#  'Adam/output/kernel/v/IsInitialized/VarIsInitializedOp',
#  'Adam/output/kernel/v/Assign',
#  'Adam/output/kernel/v/Read/ReadVariableOp',
#  'Adam/output/bias/v/Initializer/zeros',
#  'Adam/output/bias/v',
#  'Adam/output/bias/v/IsInitialized/VarIsInitializedOp',
#  'Adam/output/bias/v/Assign',
#  'Adam/output/bias/v/Read/ReadVariableOp',
#  'Adam/Adam/update_conv1/kernel/Const',
#  'Adam/Adam/update_conv1/kernel/ReadVariableOp',
#  'Adam/Adam/update_conv1/kernel/add/y',
#  'Adam/Adam/update_conv1/kernel/add',
#  'Adam/Adam/update_conv1/kernel/Cast',
#  'Adam/Adam/update_conv1/kernel/Pow/ReadVariableOp',
#  'Adam/Adam/update_conv1/kernel/Pow',
#  'Adam/Adam/update_conv1/kernel/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_conv1/kernel/Pow_1',
#  'Adam/Adam/update_conv1/kernel/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_conv1/kernel/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_conv1/kernel/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_conv1/kernel/ResourceApplyAdam',
#  'Adam/Adam/update_conv1/bias/Const',
#  'Adam/Adam/update_conv1/bias/ReadVariableOp',
#  'Adam/Adam/update_conv1/bias/add/y',
#  'Adam/Adam/update_conv1/bias/add',
#  'Adam/Adam/update_conv1/bias/Cast',
#  'Adam/Adam/update_conv1/bias/Pow/ReadVariableOp',
#  'Adam/Adam/update_conv1/bias/Pow',
#  'Adam/Adam/update_conv1/bias/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_conv1/bias/Pow_1',
#  'Adam/Adam/update_conv1/bias/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_conv1/bias/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_conv1/bias/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_conv1/bias/ResourceApplyAdam',
#  'Adam/Adam/update_conv2/kernel/Const',
#  'Adam/Adam/update_conv2/kernel/ReadVariableOp',
#  'Adam/Adam/update_conv2/kernel/add/y',
#  'Adam/Adam/update_conv2/kernel/add',
#  'Adam/Adam/update_conv2/kernel/Cast',
#  'Adam/Adam/update_conv2/kernel/Pow/ReadVariableOp',
#  'Adam/Adam/update_conv2/kernel/Pow',
#  'Adam/Adam/update_conv2/kernel/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_conv2/kernel/Pow_1',
#  'Adam/Adam/update_conv2/kernel/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_conv2/kernel/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_conv2/kernel/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_conv2/kernel/ResourceApplyAdam',
#  'Adam/Adam/update_conv2/bias/Const',
#  'Adam/Adam/update_conv2/bias/ReadVariableOp',
#  'Adam/Adam/update_conv2/bias/add/y',
#  'Adam/Adam/update_conv2/bias/add',
#  'Adam/Adam/update_conv2/bias/Cast',
#  'Adam/Adam/update_conv2/bias/Pow/ReadVariableOp',
#  'Adam/Adam/update_conv2/bias/Pow',
#  'Adam/Adam/update_conv2/bias/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_conv2/bias/Pow_1',
#  'Adam/Adam/update_conv2/bias/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_conv2/bias/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_conv2/bias/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_conv2/bias/ResourceApplyAdam',
#  'Adam/Adam/update_conv3/kernel/Const',
#  'Adam/Adam/update_conv3/kernel/ReadVariableOp',
#  'Adam/Adam/update_conv3/kernel/add/y',
#  'Adam/Adam/update_conv3/kernel/add',
#  'Adam/Adam/update_conv3/kernel/Cast',
#  'Adam/Adam/update_conv3/kernel/Pow/ReadVariableOp',
#  'Adam/Adam/update_conv3/kernel/Pow',
#  'Adam/Adam/update_conv3/kernel/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_conv3/kernel/Pow_1',
#  'Adam/Adam/update_conv3/kernel/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_conv3/kernel/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_conv3/kernel/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_conv3/kernel/ResourceApplyAdam',
#  'Adam/Adam/update_conv3/bias/Const',
#  'Adam/Adam/update_conv3/bias/ReadVariableOp',
#  'Adam/Adam/update_conv3/bias/add/y',
#  'Adam/Adam/update_conv3/bias/add',
#  'Adam/Adam/update_conv3/bias/Cast',
#  'Adam/Adam/update_conv3/bias/Pow/ReadVariableOp',
#  'Adam/Adam/update_conv3/bias/Pow',
#  'Adam/Adam/update_conv3/bias/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_conv3/bias/Pow_1',
#  'Adam/Adam/update_conv3/bias/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_conv3/bias/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_conv3/bias/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_conv3/bias/ResourceApplyAdam',
#  'Adam/Adam/update_fc1/kernel/Const',
#  'Adam/Adam/update_fc1/kernel/ReadVariableOp',
#  'Adam/Adam/update_fc1/kernel/add/y',
#  'Adam/Adam/update_fc1/kernel/add',
#  'Adam/Adam/update_fc1/kernel/Cast',
#  'Adam/Adam/update_fc1/kernel/Pow/ReadVariableOp',
#  'Adam/Adam/update_fc1/kernel/Pow',
#  'Adam/Adam/update_fc1/kernel/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_fc1/kernel/Pow_1',
#  'Adam/Adam/update_fc1/kernel/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_fc1/kernel/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_fc1/kernel/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_fc1/kernel/ResourceApplyAdam',
#  'Adam/Adam/update_fc1/bias/Const',
#  'Adam/Adam/update_fc1/bias/ReadVariableOp',
#  'Adam/Adam/update_fc1/bias/add/y',
#  'Adam/Adam/update_fc1/bias/add',
#  'Adam/Adam/update_fc1/bias/Cast',
#  'Adam/Adam/update_fc1/bias/Pow/ReadVariableOp',
#  'Adam/Adam/update_fc1/bias/Pow',
#  'Adam/Adam/update_fc1/bias/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_fc1/bias/Pow_1',
#  'Adam/Adam/update_fc1/bias/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_fc1/bias/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_fc1/bias/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_fc1/bias/ResourceApplyAdam',
#  'Adam/Adam/update_output/kernel/Const',
#  'Adam/Adam/update_output/kernel/ReadVariableOp',
#  'Adam/Adam/update_output/kernel/add/y',
#  'Adam/Adam/update_output/kernel/add',
#  'Adam/Adam/update_output/kernel/Cast',
#  'Adam/Adam/update_output/kernel/Pow/ReadVariableOp',
#  'Adam/Adam/update_output/kernel/Pow',
#  'Adam/Adam/update_output/kernel/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_output/kernel/Pow_1',
#  'Adam/Adam/update_output/kernel/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_output/kernel/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_output/kernel/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_output/kernel/ResourceApplyAdam',
#  'Adam/Adam/update_output/bias/Const',
#  'Adam/Adam/update_output/bias/ReadVariableOp',
#  'Adam/Adam/update_output/bias/add/y',
#  'Adam/Adam/update_output/bias/add',
#  'Adam/Adam/update_output/bias/Cast',
#  'Adam/Adam/update_output/bias/Pow/ReadVariableOp',
#  'Adam/Adam/update_output/bias/Pow',
#  'Adam/Adam/update_output/bias/Pow_1/ReadVariableOp',
#  'Adam/Adam/update_output/bias/Pow_1',
#  'Adam/Adam/update_output/bias/ResourceApplyAdam/ReadVariableOp',
#  'Adam/Adam/update_output/bias/ResourceApplyAdam/ReadVariableOp_1',
#  'Adam/Adam/update_output/bias/ResourceApplyAdam/ReadVariableOp_2',
#  'Adam/Adam/update_output/bias/ResourceApplyAdam',
#  'Adam/Adam/Const',
#  'Adam/Adam/AssignAddVariableOp',
#  'Adam/Adam/ReadVariableOp',
#  'training_1/group_deps',
#  'VarIsInitializedOp_12',
#  'VarIsInitializedOp_13',
#  'VarIsInitializedOp_14',
#  'VarIsInitializedOp_15',
#  'VarIsInitializedOp_16',
#  'VarIsInitializedOp_17',
#  'VarIsInitializedOp_18',
#  'VarIsInitializedOp_19',
#  'VarIsInitializedOp_20',
#  'VarIsInitializedOp_21',
#  'VarIsInitializedOp_22',
#  'VarIsInitializedOp_23',
#  'VarIsInitializedOp_24',
#  'VarIsInitializedOp_25',
#  'VarIsInitializedOp_26',
#  'VarIsInitializedOp_27',
#  'VarIsInitializedOp_28',
#  'VarIsInitializedOp_29',
#  'VarIsInitializedOp_30',
#  'VarIsInitializedOp_31',
#  'VarIsInitializedOp_32',
#  'VarIsInitializedOp_33',
#  'VarIsInitializedOp_34',
#  'VarIsInitializedOp_35',
#  'VarIsInitializedOp_36',
#  'init_1',
#  'input_img_1',
#  'conv1_1/kernel/Initializer/random_uniform/shape',
#  'conv1_1/kernel/Initializer/random_uniform/min',
#  'conv1_1/kernel/Initializer/random_uniform/max',
#  'conv1_1/kernel/Initializer/random_uniform/RandomUniform',
#  'conv1_1/kernel/Initializer/random_uniform/sub',
#  'conv1_1/kernel/Initializer/random_uniform/mul',
#  'conv1_1/kernel/Initializer/random_uniform',
#  'conv1_1/kernel',
#  'conv1_1/kernel/IsInitialized/VarIsInitializedOp',
#  'conv1_1/kernel/Assign',
#  'conv1_1/kernel/Read/ReadVariableOp',
#  'conv1_1/bias/Initializer/zeros',
#  'conv1_1/bias',
#  'conv1_1/bias/IsInitialized/VarIsInitializedOp',
#  'conv1_1/bias/Assign',
#  'conv1_1/bias/Read/ReadVariableOp',
#  'conv1_1/dilation_rate',
#  'conv1_1/Conv2D/ReadVariableOp',
#  'conv1_1/Conv2D',
#  'conv1_1/BiasAdd/ReadVariableOp',
#  'conv1_1/BiasAdd',
#  'conv1_1/Relu',
#  'max_pooling2d_3/MaxPool',
#  'conv2_1/kernel/Initializer/random_uniform/shape',
#  'conv2_1/kernel/Initializer/random_uniform/min',
#  'conv2_1/kernel/Initializer/random_uniform/max',
#  'conv2_1/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2_1/kernel/Initializer/random_uniform/sub',
#  'conv2_1/kernel/Initializer/random_uniform/mul',
#  'conv2_1/kernel/Initializer/random_uniform',
#  'conv2_1/kernel',
#  'conv2_1/kernel/IsInitialized/VarIsInitializedOp',
#  'conv2_1/kernel/Assign',
#  'conv2_1/kernel/Read/ReadVariableOp',
#  'conv2_1/bias/Initializer/zeros',
#  'conv2_1/bias',
#  'conv2_1/bias/IsInitialized/VarIsInitializedOp',
#  'conv2_1/bias/Assign',
#  'conv2_1/bias/Read/ReadVariableOp',
#  'conv2_1/dilation_rate',
#  'conv2_1/Conv2D/ReadVariableOp',
#  'conv2_1/Conv2D',
#  'conv2_1/BiasAdd/ReadVariableOp',
#  'conv2_1/BiasAdd',
#  'conv2_1/Relu',
#  'max_pooling2d_4/MaxPool',
#  'conv3_1/kernel/Initializer/random_uniform/shape',
#  'conv3_1/kernel/Initializer/random_uniform/min',
#  'conv3_1/kernel/Initializer/random_uniform/max',
#  'conv3_1/kernel/Initializer/random_uniform/RandomUniform',
#  'conv3_1/kernel/Initializer/random_uniform/sub',
#  'conv3_1/kernel/Initializer/random_uniform/mul',
#  'conv3_1/kernel/Initializer/random_uniform',
#  'conv3_1/kernel',
#  'conv3_1/kernel/IsInitialized/VarIsInitializedOp',
#  'conv3_1/kernel/Assign',
#  'conv3_1/kernel/Read/ReadVariableOp',
#  'conv3_1/bias/Initializer/zeros',
#  'conv3_1/bias',
#  'conv3_1/bias/IsInitialized/VarIsInitializedOp',
#  'conv3_1/bias/Assign',
#  'conv3_1/bias/Read/ReadVariableOp',
#  'conv3_1/dilation_rate',
#  'conv3_1/Conv2D/ReadVariableOp',
#  'conv3_1/Conv2D',
#  'conv3_1/BiasAdd/ReadVariableOp',
#  'conv3_1/BiasAdd',
#  'conv3_1/Relu',
#  'max_pooling2d_5/MaxPool',
#  'flatten_1/Shape',
#  'flatten_1/strided_slice/stack',
#  'flatten_1/strided_slice/stack_1',
#  'flatten_1/strided_slice/stack_2',
#  'flatten_1/strided_slice',
#  'flatten_1/Reshape/shape/1',
#  'flatten_1/Reshape/shape',
#  'flatten_1/Reshape',
#  'input_hist_1',
#  'concatenate_1/concat/axis',
#  'concatenate_1/concat',
#  'fc1_1/kernel/Initializer/random_uniform/shape',
#  'fc1_1/kernel/Initializer/random_uniform/min',
#  'fc1_1/kernel/Initializer/random_uniform/max',
#  'fc1_1/kernel/Initializer/random_uniform/RandomUniform',
#  'fc1_1/kernel/Initializer/random_uniform/sub',
#  'fc1_1/kernel/Initializer/random_uniform/mul',
#  'fc1_1/kernel/Initializer/random_uniform',
#  'fc1_1/kernel',
#  'fc1_1/kernel/IsInitialized/VarIsInitializedOp',
#  'fc1_1/kernel/Assign',
#  'fc1_1/kernel/Read/ReadVariableOp',
#  'fc1_1/bias/Initializer/zeros',
#  'fc1_1/bias',
#  'fc1_1/bias/IsInitialized/VarIsInitializedOp',
#  'fc1_1/bias/Assign',
#  'fc1_1/bias/Read/ReadVariableOp',
#  'fc1_1/MatMul/ReadVariableOp',
#  'fc1_1/MatMul',
#  'fc1_1/BiasAdd/ReadVariableOp',
#  'fc1_1/BiasAdd',
#  'fc1_1/Relu',
#  'output_1/kernel/Initializer/random_uniform/shape',
#  'output_1/kernel/Initializer/random_uniform/min',
#  'output_1/kernel/Initializer/random_uniform/max',
#  'output_1/kernel/Initializer/random_uniform/RandomUniform',
#  'output_1/kernel/Initializer/random_uniform/sub',
#  'output_1/kernel/Initializer/random_uniform/mul',
#  'output_1/kernel/Initializer/random_uniform',
#  'output_1/kernel',
#  'output_1/kernel/IsInitialized/VarIsInitializedOp',
#  'output_1/kernel/Assign',
#  'output_1/kernel/Read/ReadVariableOp',
#  'output_1/bias/Initializer/zeros',
#  'output_1/bias',
#  'output_1/bias/IsInitialized/VarIsInitializedOp',
#  'output_1/bias/Assign',
#  'output_1/bias/Read/ReadVariableOp',
#  'output_1/MatMul/ReadVariableOp',
#  'output_1/MatMul',
#  'output_1/BiasAdd/ReadVariableOp',
#  'output_1/BiasAdd',
#  'output_1/Softmax',
#  'total_1/Initializer/zeros',
#  'total_1',
#  'total_1/IsInitialized/VarIsInitializedOp',
#  'total_1/Assign',
#  'total_1/Read/ReadVariableOp',
#  'count_1/Initializer/zeros',
#  'count_1',
#  'count_1/IsInitialized/VarIsInitializedOp',
#  'count_1/Assign',
#  'count_1/Read/ReadVariableOp',
#  'output_target_1',
#  'metrics_2/categorical_accuracy/ArgMax/dimension',
#  'metrics_2/categorical_accuracy/ArgMax',
#  'metrics_2/categorical_accuracy/ArgMax_1/dimension',
#  'metrics_2/categorical_accuracy/ArgMax_1',
#  'metrics_2/categorical_accuracy/Equal',
#  'metrics_2/categorical_accuracy/Cast',
#  'metrics_2/categorical_accuracy/Const',
#  'metrics_2/categorical_accuracy/Sum',
#  'metrics_2/categorical_accuracy/AssignAddVariableOp',
#  'metrics_2/categorical_accuracy/ReadVariableOp',
#  'metrics_2/categorical_accuracy/Size',
#  'metrics_2/categorical_accuracy/Cast_1',
#  'metrics_2/categorical_accuracy/AssignAddVariableOp_1',
#  'metrics_2/categorical_accuracy/ReadVariableOp_1',
#  'metrics_2/categorical_accuracy/div_no_nan/ReadVariableOp',
#  'metrics_2/categorical_accuracy/div_no_nan/ReadVariableOp_1',
#  'metrics_2/categorical_accuracy/div_no_nan',
#  'metrics_2/categorical_accuracy/Identity',
#  'loss_1/output_loss/Const',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Rank',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Shape',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Rank_1',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Shape_1',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Sub/y',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Sub',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Slice/begin',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Slice/size',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Slice',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/concat/values_0',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/concat/axis',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/concat',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Reshape',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Rank_2',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Shape_2',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Sub_1/y',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Sub_1',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Slice_1/begin',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Slice_1/size',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Slice_1',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/concat_1/values_0',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/concat_1/axis',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/concat_1',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Reshape_1',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Sub_2/y',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Sub_2',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Slice_2/begin',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Slice_2/size',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Slice_2',
#  'loss_1/output_loss/softmax_cross_entropy_with_logits/Reshape_2',
#  'loss_1/output_loss/weighted_loss/Const',
#  'loss_1/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/weights/shape',
#  'loss_1/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/weights/rank',
#  'loss_1/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/values/shape',
#  'loss_1/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/values/rank',
#  'loss_1/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/static_scalar_check_success',
#  'loss_1/output_loss/weighted_loss/broadcast_weights/ones_like/Shape',
#  'loss_1/output_loss/weighted_loss/broadcast_weights/ones_like/Const',
#  'loss_1/output_loss/weighted_loss/broadcast_weights/ones_like',
#  'loss_1/output_loss/weighted_loss/broadcast_weights',
#  'loss_1/output_loss/weighted_loss/Mul',
#  'loss_1/output_loss/Const_1',
#  'loss_1/output_loss/Sum',
#  'loss_1/output_loss/num_elements',
#  'loss_1/output_loss/num_elements/Cast',
#  'loss_1/output_loss/Const_2',
#  'loss_1/output_loss/Sum_1',
#  'loss_1/output_loss/value',
#  'loss_1/mul/x',
#  'loss_1/mul',
#  'input_img_2',
#  'conv1_2/kernel/Initializer/random_uniform/shape',
#  'conv1_2/kernel/Initializer/random_uniform/min',
#  'conv1_2/kernel/Initializer/random_uniform/max',
#  'conv1_2/kernel/Initializer/random_uniform/RandomUniform',
#  'conv1_2/kernel/Initializer/random_uniform/sub',
#  'conv1_2/kernel/Initializer/random_uniform/mul',
#  'conv1_2/kernel/Initializer/random_uniform',
#  'conv1_2/kernel',
#  'conv1_2/kernel/IsInitialized/VarIsInitializedOp',
#  'conv1_2/kernel/Assign',
#  'conv1_2/kernel/Read/ReadVariableOp',
#  'conv1_2/bias/Initializer/zeros',
#  'conv1_2/bias',
#  'conv1_2/bias/IsInitialized/VarIsInitializedOp',
#  'conv1_2/bias/Assign',
#  'conv1_2/bias/Read/ReadVariableOp',
#  'conv1_2/dilation_rate',
#  'conv1_2/Conv2D/ReadVariableOp',
#  'conv1_2/Conv2D',
#  'conv1_2/BiasAdd/ReadVariableOp',
#  'conv1_2/BiasAdd',
#  'conv1_2/Relu',
#  'max_pooling2d_6/MaxPool',
#  'conv2_2/kernel/Initializer/random_uniform/shape',
#  'conv2_2/kernel/Initializer/random_uniform/min',
#  'conv2_2/kernel/Initializer/random_uniform/max',
#  'conv2_2/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2_2/kernel/Initializer/random_uniform/sub',
#  'conv2_2/kernel/Initializer/random_uniform/mul',
#  'conv2_2/kernel/Initializer/random_uniform',
#  'conv2_2/kernel',
#  'conv2_2/kernel/IsInitialized/VarIsInitializedOp',
#  'conv2_2/kernel/Assign',
#  'conv2_2/kernel/Read/ReadVariableOp',
#  'conv2_2/bias/Initializer/zeros',
#  'conv2_2/bias',
#  'conv2_2/bias/IsInitialized/VarIsInitializedOp',
#  'conv2_2/bias/Assign',
#  'conv2_2/bias/Read/ReadVariableOp',
#  'conv2_2/dilation_rate',
#  'conv2_2/Conv2D/ReadVariableOp',
#  'conv2_2/Conv2D',
#  'conv2_2/BiasAdd/ReadVariableOp',
#  'conv2_2/BiasAdd',
#  'conv2_2/Relu',
#  'max_pooling2d_7/MaxPool',
#  'conv3_2/kernel/Initializer/random_uniform/shape',
#  'conv3_2/kernel/Initializer/random_uniform/min',
#  'conv3_2/kernel/Initializer/random_uniform/max',
#  'conv3_2/kernel/Initializer/random_uniform/RandomUniform',
#  'conv3_2/kernel/Initializer/random_uniform/sub',
#  'conv3_2/kernel/Initializer/random_uniform/mul',
#  'conv3_2/kernel/Initializer/random_uniform',
#  'conv3_2/kernel',
#  'conv3_2/kernel/IsInitialized/VarIsInitializedOp',
#  'conv3_2/kernel/Assign',
#  'conv3_2/kernel/Read/ReadVariableOp',
#  'conv3_2/bias/Initializer/zeros',
#  'conv3_2/bias',
#  'conv3_2/bias/IsInitialized/VarIsInitializedOp',
#  'conv3_2/bias/Assign',
#  'conv3_2/bias/Read/ReadVariableOp',
#  'conv3_2/dilation_rate',
#  'conv3_2/Conv2D/ReadVariableOp',
#  'conv3_2/Conv2D',
#  'conv3_2/BiasAdd/ReadVariableOp',
#  'conv3_2/BiasAdd',
#  'conv3_2/Relu',
#  'max_pooling2d_8/MaxPool',
#  'flatten_2/Shape',
#  'flatten_2/strided_slice/stack',
#  'flatten_2/strided_slice/stack_1',
#  'flatten_2/strided_slice/stack_2',
#  'flatten_2/strided_slice',
#  'flatten_2/Reshape/shape/1',
#  'flatten_2/Reshape/shape',
#  'flatten_2/Reshape',
#  'input_hist_2',
#  'concatenate_2/concat/axis',
#  'concatenate_2/concat',
#  'fc1_2/kernel/Initializer/random_uniform/shape',
#  'fc1_2/kernel/Initializer/random_uniform/min',
#  'fc1_2/kernel/Initializer/random_uniform/max',
#  'fc1_2/kernel/Initializer/random_uniform/RandomUniform',
#  'fc1_2/kernel/Initializer/random_uniform/sub',
#  'fc1_2/kernel/Initializer/random_uniform/mul',
#  'fc1_2/kernel/Initializer/random_uniform',
#  'fc1_2/kernel',
#  'fc1_2/kernel/IsInitialized/VarIsInitializedOp',
#  'fc1_2/kernel/Assign',
#  'fc1_2/kernel/Read/ReadVariableOp',
#  'fc1_2/bias/Initializer/zeros',
#  'fc1_2/bias',
#  'fc1_2/bias/IsInitialized/VarIsInitializedOp',
#  'fc1_2/bias/Assign',
#  'fc1_2/bias/Read/ReadVariableOp',
#  'fc1_2/MatMul/ReadVariableOp',
#  'fc1_2/MatMul',
#  'fc1_2/BiasAdd/ReadVariableOp',
#  'fc1_2/BiasAdd',
#  'fc1_2/Relu',
#  'output_2/kernel/Initializer/random_uniform/shape',
#  'output_2/kernel/Initializer/random_uniform/min',
#  'output_2/kernel/Initializer/random_uniform/max',
#  'output_2/kernel/Initializer/random_uniform/RandomUniform',
#  'output_2/kernel/Initializer/random_uniform/sub',
#  'output_2/kernel/Initializer/random_uniform/mul',
#  'output_2/kernel/Initializer/random_uniform',
#  'output_2/kernel',
#  'output_2/kernel/IsInitialized/VarIsInitializedOp',
#  'output_2/kernel/Assign',
#  'output_2/kernel/Read/ReadVariableOp',
#  'output_2/bias/Initializer/zeros',
#  'output_2/bias',
#  'output_2/bias/IsInitialized/VarIsInitializedOp',
#  'output_2/bias/Assign',
#  'output_2/bias/Read/ReadVariableOp',
#  'output_2/MatMul/ReadVariableOp',
#  'output_2/MatMul',
#  'output_2/BiasAdd/ReadVariableOp',
#  'output_2/BiasAdd',
#  'output_2/Softmax',
#  'total_2/Initializer/zeros',
#  'total_2',
#  'total_2/IsInitialized/VarIsInitializedOp',
#  'total_2/Assign',
#  'total_2/Read/ReadVariableOp',
#  'count_2/Initializer/zeros',
#  'count_2',
#  'count_2/IsInitialized/VarIsInitializedOp',
#  'count_2/Assign',
#  'count_2/Read/ReadVariableOp',
#  'output_target_2',
#  'metrics_4/categorical_accuracy/ArgMax/dimension',
#  'metrics_4/categorical_accuracy/ArgMax',
#  'metrics_4/categorical_accuracy/ArgMax_1/dimension',
#  'metrics_4/categorical_accuracy/ArgMax_1',
#  'metrics_4/categorical_accuracy/Equal',
#  'metrics_4/categorical_accuracy/Cast',
#  'metrics_4/categorical_accuracy/Const',
#  'metrics_4/categorical_accuracy/Sum',
#  'metrics_4/categorical_accuracy/AssignAddVariableOp',
#  'metrics_4/categorical_accuracy/ReadVariableOp',
#  'metrics_4/categorical_accuracy/Size',
#  'metrics_4/categorical_accuracy/Cast_1',
#  'metrics_4/categorical_accuracy/AssignAddVariableOp_1',
#  'metrics_4/categorical_accuracy/ReadVariableOp_1',
#  'metrics_4/categorical_accuracy/div_no_nan/ReadVariableOp',
#  'metrics_4/categorical_accuracy/div_no_nan/ReadVariableOp_1',
#  'metrics_4/categorical_accuracy/div_no_nan',
#  'metrics_4/categorical_accuracy/Identity',
#  'loss_2/output_loss/Const',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Rank',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Shape',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Rank_1',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Shape_1',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Sub/y',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Sub',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Slice/begin',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Slice/size',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Slice',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/concat/values_0',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/concat/axis',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/concat',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Reshape',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Rank_2',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Shape_2',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Sub_1/y',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Sub_1',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Slice_1/begin',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Slice_1/size',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Slice_1',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/concat_1/values_0',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/concat_1/axis',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/concat_1',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Reshape_1',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Sub_2/y',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Sub_2',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Slice_2/begin',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Slice_2/size',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Slice_2',
#  'loss_2/output_loss/softmax_cross_entropy_with_logits/Reshape_2',
#  'loss_2/output_loss/weighted_loss/Const',
#  'loss_2/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/weights/shape',
#  'loss_2/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/weights/rank',
#  'loss_2/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/values/shape',
#  'loss_2/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/values/rank',
#  'loss_2/output_loss/weighted_loss/broadcast_weights/assert_broadcastable/static_scalar_check_success',
#  'loss_2/output_loss/weighted_loss/broadcast_weights/ones_like/Shape',
#  'loss_2/output_loss/weighted_loss/broadcast_weights/ones_like/Const',
#  'loss_2/output_loss/weighted_loss/broadcast_weights/ones_like',
#  ...]
